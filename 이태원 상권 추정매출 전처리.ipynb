# %%
import pandas as pd
import numpy as np

# %%
data3 = pd.read_csv('./data_2018.csv')

# %%
data_store3 = data3[data3['상권_코드_명'].str.contains('이태원')]

# %%
data_store3
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 424        2018         1        A       골목상권  1000071      이태원로54길  CS300001
# 899        2018         1        D       발달상권  1001150  서울 용산구 이태원역  CS200023
# 900        2018         1        R       전통시장  1001292      이태원제일시장  CS100005
# 1815       2018         1        D       발달상권  1001150  서울 용산구 이태원역  CS300018
# 1816       2018         1        D       발달상권  1001150  서울 용산구 이태원역  CS300021
# ...         ...       ...      ...        ...      ...          ...       ...
# 160928     2018         4        U       관광특구  1001491     이태원 관광특구  CS300007
# 161139     2018         4        R       전통시장  1001292      이태원제일시장  CS300020
# 161758     2018         4        A       골목상권  1000071      이태원로54길  CS100001
# 161901     2018         4        U       관광특구  1001491     이태원 관광특구  CS100006
# 162348     2018         4        D       발달상권  1001150  서울 용산구 이태원역  CS200028
#
# ...

# %%
data_store3 = data_store3.loc[:,['기준_년_코드','기준_분기_코드','상권_구분_코드_명','서비스_업종_코드_명','분기당_매출_금액']]

# %%
data_store3
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드_명 서비스_업종_코드_명   분기당_매출_금액
# 424        2018         1       골목상권        슈퍼마켓    87385043
# 899        2018         1       발달상권      통신기기수리    12081789
# 900        2018         1       전통시장         제과점     9436612
# 1815       2018         1       발달상권         의약품   452895152
# 1816       2018         1       발달상권          문구    47276157
# ...         ...       ...        ...         ...         ...
# 160928     2018         4       관광특구        육류판매  1136944275
# 161139     2018         4       전통시장          서적     1981149
# 161758     2018         4       골목상권       한식음식점  3308244909
# 161901     2018         4       관광특구      패스트푸드점  3866472486
# 162348     2018         4       발달상권         미용실   193954327
#
# [681 rows x 5 columns]

# %%
data1 = pd.read_csv('C:/Users/LeeHB/Desktop/이태원 2019 - 2020/data_2019.csv', encoding='euc-kr')

# %%
data1
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0          2019         1        A       골목상권  1000985     암사길  CS200003
# 1          2019         1        A       골목상권  1000267  돌곶이로8길  CS200037
# 2          2019         1        R       전통시장  1001445    영도시장  CS300027
# 3          2019         1        A       골목상권  1000789  난곡로24길  CS300017
# 4          2019         1        A       골목상권  1000930  언주로81길  CS200001
# ...         ...       ...      ...        ...      ...     ...       ...
# 135573     2019         4        R       전통시장  1001469    양재시장  CS300011
# 135574     2019         4        A       골목상권  1000181  망우로21길  CS100004
# 135575     2019         4        A       골목상권  1000441   세무서2길  CS300002
# 135576     2019         4        D       발달상권  1001044   양재역_3  CS200001
# 135577     2019         4        A       골목상권  1000736  노량진로6길  CS300002
#
#        서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  \
# ...

# %%
data_store1 = data1[data1['상권_코드_명'].str.contains('이태원')]

# %%
data_store1
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 203        2019         1        U       관광특구  1001491     이태원 관광특구  CS200024
# 215        2019         1        A       골목상권  1000070      이태원로27길  CS100005
# 216        2019         1        A       골목상권  1000070      이태원로27길  CS300002
# 218        2019         1        D       발달상권  1001150  서울 용산구 이태원역  CS300002
# 868        2019         1        A       골목상권  1000070      이태원로27길  CS100006
# ...         ...       ...      ...        ...      ...          ...       ...
# 135348     2019         4        U       관광특구  1001491     이태원 관광특구  CS300020
# 135376     2019         4        D       발달상권  1001150  서울 용산구 이태원역  CS100003
# 135478     2019         4        D       발달상권  1001150  서울 용산구 이태원역  CS300018
# 135544     2019         4        U       관광특구  1001491     이태원 관광특구  CS200017
# 135551     2019         4        U       관광특구  1001491     이태원 관광특구  CS300016
#
# ...

# %%
data_store1 = data_store1.loc[:,['기준_년_코드','기준_분기_코드','상권_구분_코드_명','서비스_업종_코드_명','분기당_매출_금액']]

# %%
data_store1
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드_명 서비스_업종_코드_명   분기당_매출_금액
# 203        2019         1       관광특구       스포츠클럽   394722099
# 215        2019         1       골목상권         제과점    45137684
# 216        2019         1       골목상권         편의점  1026617334
# 218        2019         1       발달상권         편의점  3024593222
# 868        2019         1       골목상권      패스트푸드점    14727134
# ...         ...       ...        ...         ...         ...
# 135348     2019         4       관광특구          서적  1192054921
# 135376     2019         4       발달상권       일식음식점   191068729
# 135478     2019         4       발달상권         의약품   428190681
# 135544     2019         4       관광특구       골프연습장    51038556
# 135551     2019         4       관광특구          안경   139063293
#
# [557 rows x 5 columns]

# %%
data_store1_sum = data_store1.groupby(['기준_년_코드','서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명']).sum().reset_index()

# %%
data_store1_sum['서비스_업종_코드_명'].unique()
# Out:
# array(['가구', '가방', '가전제품수리', '골프연습장', '네일숍', '노래방', '당구장', '문구', '미용실',
#        '반찬가게', '분식전문점', '서적', '섬유제품', '세탁소', '수산물판매', '슈퍼마켓', '스포츠클럽',
#        '시계및귀금속', '신발', '안경', '애완동물', '양식음식점', '여관', '예술학원', '운동/경기용품',
#        '육류판매', '의료기기', '의약품', '일반의류', '일반의원', '일식음식점', '자동차미용', '자동차수리',
#        '전자상거래업', '제과점', '조명용품', '중식음식점', '철물점', '치과의원', '치킨전문점', '커피-음료',
#        '패스트푸드점', '편의점', '피부관리실', '한식음식점', '한의원', '핸드폰', '호프-간이주점', '화장품',
#        '화초'], dtype=object)

# %%
data_store1_sum.to_csv('./resulst.csv',encoding='euc-kr')

# %%
data_store1 = data_store1.sort_values(by=['서비스_업종_코드_명','기준_분기_코드','기준_년_코드','상권_구분_코드_명'],ascending=True)

# %%
data_store1.to_csv('C:/Users/LeeHB/Desktop/이태원 2019 - 2020/store1.csv',encoding='euc-kr')

# %%
data2 = pd.read_csv('C:/Users/LeeHB/Desktop/이태원 2019 - 2020/data_2020.csv',encoding='euc-kr')

# %%
data2
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2020         3        R       전통시장  1001370       역촌중앙시장  CS300009
# 1          2020         3        R       전통시장  1001386         신수시장  CS200001
# 2          2020         1        A       골목상권  1000022         창신2길  CS200001
# 3          2020         3        R       전통시장  1001402     신월6동골목시장  CS100009
# 4          2020         1        A       골목상권  1000001          계동길  CS100001
# ...         ...       ...      ...        ...      ...          ...       ...
# 132316     2020         2        R       전통시장  1001477         마천시장  CS100008
# 132317     2020         2        R       전통시장  1001487         천호시장  CS200028
# 132318     2020         2        R       전통시장  1001488       성내골목시장  CS200030
# 132319     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS200030
# 132320     2020         2        U       관광특구  1001496  강남 마이스 관광특구  CS300043
#
# ...

# %%
data_store2 = data2[data2['상권_코드_명'].str.contains('이태원')]

# %%
data_store2
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 1168       2020         1        A       골목상권  1000070      이태원로27길  CS100001
# 1169       2020         1        A       골목상권  1000070      이태원로27길  CS100003
# 1170       2020         1        A       골목상권  1000070      이태원로27길  CS100004
# 1171       2020         1        A       골목상권  1000070      이태원로27길  CS100008
# 1172       2020         1        A       골목상권  1000070      이태원로27길  CS100009
# ...         ...       ...      ...        ...      ...          ...       ...
# 131844     2020         4        U       관광특구  1001491     이태원 관광특구  CS300029
# 131845     2020         4        U       관광특구  1001491     이태원 관광특구  CS300031
# 131846     2020         4        U       관광특구  1001491     이태원 관광특구  CS300036
# 131847     2020         4        U       관광특구  1001491     이태원 관광특구  CS300043
# 132287     2020         2        D       발달상권  1001150  서울 용산구 이태원역  CS200029
#
# ...

# %%
total_data = data_store1.append(data_store2)

# %%
total_data = total_data.append(data_store3)

# %%
total_data
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명      상권_코드      상권_코드_명  \
# 203        2019         1        U       관광특구  1001491.0     이태원 관광특구
# 215        2019         1        A       골목상권  1000070.0      이태원로27길
# 216        2019         1        A       골목상권  1000070.0      이태원로27길
# 218        2019         1        D       발달상권  1001150.0  서울 용산구 이태원역
# 868        2019         1        A       골목상권  1000070.0      이태원로27길
# ...         ...       ...      ...        ...        ...          ...
# 160928     2018         4      NaN       관광특구        NaN          NaN
# 161139     2018         4      NaN       전통시장        NaN          NaN
# 161758     2018         4      NaN       골목상권        NaN          NaN
# 161901     2018         4      NaN       관광특구        NaN          NaN
# 162348     2018         4      NaN       발달상권        NaN          NaN
#
#        서비스_업종_코드 서비스_업종_코드_명     분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  \
# ...

# %%
total_data_col = total_data.loc[:, ['기준_년_코드','기준_분기_코드','상권_구분_코드_명','서비스_업종_코드_명','분기당_매출_금액']]

# %%
total_data_col
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드_명 서비스_업종_코드_명     분기당_매출_금액
# 203        2019         1       관광특구       스포츠클럽  3.947221e+08
# 215        2019         1       골목상권         제과점  4.513768e+07
# 216        2019         1       골목상권         편의점  1.026617e+09
# 218        2019         1       발달상권         편의점  3.024593e+09
# 868        2019         1       골목상권      패스트푸드점  1.472713e+07
# ...         ...       ...        ...         ...           ...
# 160928     2018         4       관광특구        육류판매  1.136944e+09
# 161139     2018         4       전통시장          서적  1.981149e+06
# 161758     2018         4       골목상권       한식음식점  3.308245e+09
# 161901     2018         4       관광특구      패스트푸드점  3.866472e+09
# 162348     2018         4       발달상권         미용실  1.939543e+08
#
# [1770 rows x 5 columns]

# %%
total_data_col = total_data_col.groupby(['기준_년_코드','서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명']).sum()

# %%
total_data_col
# Out:
#                                            분기당_매출_금액
# 기준_년_코드 서비스_업종_코드_명 기준_분기_코드 상권_구분_코드_명
# 2018    PC방         1        관광특구         11141541.0
#                              발달상권         11141541.0
#         가구          1        관광특구        164612528.0
#                     2        관광특구         91182170.0
#                     3        관광특구         72585550.0
# ...                                              ...
# 2020    화초          3        관광특구         74888705.0
#                              발달상권         25394659.0
#                     4        골목상권         23116509.0
#                              관광특구         90018303.0
#                              발달상권         35774533.0
#
# [1554 rows x 1 columns]

# %%
total_sort = total_data_col.sort_values(by=['서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명'],ascending=True).reset_index()

# %%
total_sort
# Out:
#       기준_년_코드 서비스_업종_코드_명  기준_분기_코드 상권_구분_코드_명    분기당_매출_금액
# 0        2018         PC방         1       관광특구   11141541.0
# 1        2018         PC방         1       발달상권   11141541.0
# 2        2018          가구         1       관광특구  164612528.0
# 3        2019          가구         1       관광특구   83818931.0
# 4        2020          가구         1       관광특구   65358805.0
# ...       ...         ...       ...        ...          ...
# 1549     2019          화초         4       관광특구  146360995.0
# 1550     2020          화초         4       관광특구   90018303.0
# 1551     2018          화초         4       발달상권   77441648.0
# 1552     2019          화초         4       발달상권   72693398.0
# 1553     2020          화초         4       발달상권   35774533.0
#
# [1554 rows x 5 columns]

# %%
total_sort.to_csv('C:/Users/LeeHB/Desktop/이태원 2019 - 2020/total_sorted.csv',encoding='euc-kr')

# %%
total_sort
# Out:
#       기준_년_코드 서비스_업종_코드_명  기준_분기_코드 상권_구분_코드_명    분기당_매출_금액
# 0        2018         PC방         1       관광특구   11141541.0
# 1        2018         PC방         1       발달상권   11141541.0
# 2        2018          가구         1       관광특구  164612528.0
# 3        2019          가구         1       관광특구   83818931.0
# 4        2020          가구         1       관광특구   65358805.0
# ...       ...         ...       ...        ...          ...
# 1549     2019          화초         4       관광특구  146360995.0
# 1550     2020          화초         4       관광특구   90018303.0
# 1551     2018          화초         4       발달상권   77441648.0
# 1552     2019          화초         4       발달상권   72693398.0
# 1553     2020          화초         4       발달상권   35774533.0
#
# [1554 rows x 5 columns]

# %%
data1 = pd.read_csv('./data_2018.csv')

# %%
data_store1 = data1[data1['상권_코드_명'].str.contains('이태원')]

# %%
data_store1 = data_store1.loc[:,['기준_분기_코드','상권_구분_코드_명','서비스_업종_코드_명','분기당_매출_금액']]

# %%
data_store1
# Out:
#         기준_분기_코드 상권_구분_코드_명 서비스_업종_코드_명   분기당_매출_금액
# 424            1       골목상권        슈퍼마켓    87385043
# 899            1       발달상권      통신기기수리    12081789
# 900            1       전통시장         제과점     9436612
# 1815           1       발달상권         의약품   452895152
# 1816           1       발달상권          문구    47276157
# ...          ...        ...         ...         ...
# 160928         4       관광특구        육류판매  1136944275
# 161139         4       전통시장          서적     1981149
# 161758         4       골목상권       한식음식점  3308244909
# 161901         4       관광특구      패스트푸드점  3866472486
# 162348         4       발달상권         미용실   193954327
#
# [681 rows x 4 columns]

# %%
data_store1 = data_store1.groupby(['서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명']).sum()

# %%
data_store1
# Out:
#                                  분기당_매출_금액
# 서비스_업종_코드_명 기준_분기_코드 상권_구분_코드_명
# PC방         1        관광특구         11141541
#                      발달상권         11141541
# 가구          1        관광특구        164612528
#             2        관광특구         91182170
#             3        관광특구         72585550
# ...                                    ...
# 화초          3        관광특구        203818811
#                      발달상권         59931513
#             4        골목상권        121222651
#                      관광특구        187898257
#                      발달상권         77441648
#
# [591 rows x 1 columns]

# %%
data_store1 = data_store1.sort_values(by=['서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명'],ascending=True).reset_index()

# %%
data_store1
# Out:
#     서비스_업종_코드_명  기준_분기_코드 상권_구분_코드_명  분기당_매출_금액
# 0           PC방         1       관광특구   11141541
# 1           PC방         1       발달상권   11141541
# 2            가구         1       관광특구  164612528
# 3            가구         2       관광특구   91182170
# 4            가구         3       관광특구   72585550
# ..          ...       ...        ...        ...
# 586          화초         3       관광특구  203818811
# 587          화초         3       발달상권   59931513
# 588          화초         4       골목상권  121222651
# 589          화초         4       관광특구  187898257
# 590          화초         4       발달상권   77441648
#
# [591 rows x 4 columns]

# %%
data_store1.columns = ['서비스_업종','분기','상권','2018_분기당_매출_금액']

# %%
data_store1
# Out:
#     서비스_업종  분기    상권  2018_분기당_매출_금액
# 0      PC방   1  관광특구        11141541
# 1      PC방   1  발달상권        11141541
# 2       가구   1  관광특구       164612528
# 3       가구   2  관광특구        91182170
# 4       가구   3  관광특구        72585550
# ..     ...  ..   ...             ...
# 586     화초   3  관광특구       203818811
# 587     화초   3  발달상권        59931513
# 588     화초   4  골목상권       121222651
# 589     화초   4  관광특구       187898257
# 590     화초   4  발달상권        77441648
#
# [591 rows x 4 columns]

# %%
data2 = pd.read_csv('./data_2019.csv',encoding='euc-kr')

# %%
data_store2 = data2[data2['상권_코드_명'].str.contains('이태원')]

# %%
data_store2 = data_store2.loc[:,['기준_분기_코드','상권_구분_코드_명','서비스_업종_코드_명','분기당_매출_금액']]

# %%
data_store2
# Out:
#         기준_분기_코드 상권_구분_코드_명 서비스_업종_코드_명   분기당_매출_금액
# 203            1       관광특구       스포츠클럽   394722099
# 215            1       골목상권         제과점    45137684
# 216            1       골목상권         편의점  1026617334
# 218            1       발달상권         편의점  3024593222
# 868            1       골목상권      패스트푸드점    14727134
# ...          ...        ...         ...         ...
# 135348         4       관광특구          서적  1192054921
# 135376         4       발달상권       일식음식점   191068729
# 135478         4       발달상권         의약품   428190681
# 135544         4       관광특구       골프연습장    51038556
# 135551         4       관광특구          안경   139063293
#
# [557 rows x 4 columns]

# %%
data_store2 = data_store2.groupby(['서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명']).sum()

# %%
data_store2 = data_store2.sort_values(by=['서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명'],ascending=True).reset_index()

# %%
data_store2
# Out:
#     서비스_업종_코드_명  기준_분기_코드 상권_구분_코드_명  분기당_매출_금액
# 0            가구         1       관광특구   83818931
# 1            가구         2       관광특구   31849831
# 2            가구         3       관광특구  108941425
# 3            가구         4       관광특구   25730309
# 4            가방         1       골목상권   87329154
# ..          ...       ...        ...        ...
# 482          화초         3       관광특구  130906166
# 483          화초         3       발달상권   63985968
# 484          화초         4       골목상권   32097646
# 485          화초         4       관광특구  146360995
# 486          화초         4       발달상권   72693398
#
# [487 rows x 4 columns]

# %%
data_store2.columns = ['서비스_업종','분기','상권','2019_분기당_매출_금액']

# %%
data_store2
# Out:
#     서비스_업종  분기    상권  2019_분기당_매출_금액
# 0       가구   1  관광특구        83818931
# 1       가구   2  관광특구        31849831
# 2       가구   3  관광특구       108941425
# 3       가구   4  관광특구        25730309
# 4       가방   1  골목상권        87329154
# ..     ...  ..   ...             ...
# 482     화초   3  관광특구       130906166
# 483     화초   3  발달상권        63985968
# 484     화초   4  골목상권        32097646
# 485     화초   4  관광특구       146360995
# 486     화초   4  발달상권        72693398
#
# [487 rows x 4 columns]

# %%
data3 = pd.read_csv('data_2020.csv',encoding='euc-kr')

# %%
data_store3 = data3[data3['상권_코드_명'].str.contains('이태원')]

# %%
data_store3 = data_store3.loc[:,['기준_분기_코드','상권_구분_코드_명','서비스_업종_코드_명','분기당_매출_금액']]

# %%
data_store3
# Out:
#         기준_분기_코드 상권_구분_코드_명 서비스_업종_코드_명     분기당_매출_금액
# 1168           1       골목상권       한식음식점  1.217756e+09
# 1169           1       골목상권       일식음식점  1.928088e+07
# 1170           1       골목상권       양식음식점  5.441767e+09
# 1171           1       골목상권       분식전문점  4.137787e+08
# 1172           1       골목상권     호프-간이주점  3.786454e+09
# ...          ...        ...         ...           ...
# 131844         4       관광특구        애완동물  1.282369e+07
# 131845         4       관광특구          가구  6.411235e+07
# 131846         4       관광특구        조명용품  1.632145e+07
# 131847         4       관광특구      전자상거래업  4.676862e+08
# 132287         2       발달상권         네일숍  4.392420e+05
#
# [532 rows x 4 columns]

# %%
data_store3 = data_store3.groupby(['서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명']).sum()

# %%
data_store3 = data_store3.sort_values(by=['서비스_업종_코드_명','기준_분기_코드','상권_구분_코드_명'],ascending=True).reset_index()

# %%
data_store3
# Out:
#     서비스_업종_코드_명  기준_분기_코드 상권_구분_코드_명    분기당_매출_금액
# 0            가구         1       관광특구   65358805.0
# 1            가구         2       관광특구   91867272.0
# 2            가구         3       관광특구  101055416.0
# 3            가구         4       관광특구   64112350.0
# 4            가방         1       골목상권   48476233.0
# ..          ...       ...        ...          ...
# 471          화초         3       관광특구   74888705.0
# 472          화초         3       발달상권   25394659.0
# 473          화초         4       골목상권   23116509.0
# 474          화초         4       관광특구   90018303.0
# 475          화초         4       발달상권   35774533.0
#
# [476 rows x 4 columns]

# %%
data_store3.columns = ['서비스_업종','분기','상권','2020_분기당_매출_금액']

# %%
data_store3
# Out:
#     서비스_업종  분기    상권  2020_분기당_매출_금액
# 0       가구   1  관광특구      65358805.0
# 1       가구   2  관광특구      91867272.0
# 2       가구   3  관광특구     101055416.0
# 3       가구   4  관광특구      64112350.0
# 4       가방   1  골목상권      48476233.0
# ..     ...  ..   ...             ...
# 471     화초   3  관광특구      74888705.0
# 472     화초   3  발달상권      25394659.0
# 473     화초   4  골목상권      23116509.0
# 474     화초   4  관광특구      90018303.0
# 475     화초   4  발달상권      35774533.0
#
# [476 rows x 4 columns]

# %%
data_result = pd.merge(data_store1,data_store2, how='outer', on='서비스_업종')

# %%
data_result
# Out:
#      서비스_업종  분기_x  상권_x  2018_분기당_매출_금액  분기_y  상권_y  2019_분기당_매출_금액
# 0       PC방   1.0  관광특구      11141541.0   NaN   NaN             NaN
# 1       PC방   1.0  발달상권      11141541.0   NaN   NaN             NaN
# 2        가구   1.0  관광특구     164612528.0   1.0  관광특구    8.381893e+07
# 3        가구   1.0  관광특구     164612528.0   2.0  관광특구    3.184983e+07
# 4        가구   1.0  관광특구     164612528.0   3.0  관광특구    1.089414e+08
# ...     ...   ...   ...             ...   ...   ...             ...
# 6037     화초   4.0  발달상권      77441648.0   3.0  발달상권    6.398597e+07
# 6038     화초   4.0  발달상권      77441648.0   4.0  골목상권    3.209765e+07
# 6039     화초   4.0  발달상권      77441648.0   4.0  관광특구    1.463610e+08
# 6040     화초   4.0  발달상권      77441648.0   4.0  발달상권    7.269340e+07
# 6041   의료기기   NaN   NaN             NaN   4.0  관광특구    3.824999e+09
#
# [6042 rows x 7 columns]

# %%
data_result = pd.merge(data_result, data_store3, how='outer',on='서비스_업종')

# %%
data_result
# Out:
#       서비스_업종  분기_x  상권_x  2018_분기당_매출_금액  분기_y  상권_y  2019_분기당_매출_금액   분기  \
# 0        PC방   1.0  관광특구      11141541.0   NaN   NaN             NaN  NaN
# 1        PC방   1.0  발달상권      11141541.0   NaN   NaN             NaN  NaN
# 2         가구   1.0  관광특구     164612528.0   1.0  관광특구    8.381893e+07  1.0
# 3         가구   1.0  관광특구     164612528.0   1.0  관광특구    8.381893e+07  2.0
# 4         가구   1.0  관광특구     164612528.0   1.0  관광특구    8.381893e+07  3.0
# ...      ...   ...   ...             ...   ...   ...             ...  ...
# 74065     화초   4.0  발달상권      77441648.0   4.0  발달상권    7.269340e+07  4.0
# 74066   의료기기   NaN   NaN             NaN   4.0  관광특구    3.824999e+09  1.0
# 74067   의료기기   NaN   NaN             NaN   4.0  관광특구    3.824999e+09  2.0
# 74068   의료기기   NaN   NaN             NaN   4.0  관광특구    3.824999e+09  3.0
# 74069   의료기기   NaN   NaN             NaN   4.0  관광특구    3.824999e+09  4.0
#
#          상권  2020_분기당_매출_금액
# 0       NaN             NaN
# ...

# %%
data_store1
# Out:
#     서비스_업종  분기    상권  2018_분기당_매출_금액
# 0      PC방   1  관광특구        11141541
# 1      PC방   1  발달상권        11141541
# 2       가구   1  관광특구       164612528
# 3       가구   2  관광특구        91182170
# 4       가구   3  관광특구        72585550
# ..     ...  ..   ...             ...
# 586     화초   3  관광특구       203818811
# 587     화초   3  발달상권        59931513
# 588     화초   4  골목상권       121222651
# 589     화초   4  관광특구       187898257
# 590     화초   4  발달상권        77441648
#
# [591 rows x 4 columns]

# %%
data_store2
# Out:
#     서비스_업종  분기    상권  2019_분기당_매출_금액
# 0       가구   1  관광특구        83818931
# 1       가구   2  관광특구        31849831
# 2       가구   3  관광특구       108941425
# 3       가구   4  관광특구        25730309
# 4       가방   1  골목상권        87329154
# ..     ...  ..   ...             ...
# 482     화초   3  관광특구       130906166
# 483     화초   3  발달상권        63985968
# 484     화초   4  골목상권        32097646
# 485     화초   4  관광특구       146360995
# 486     화초   4  발달상권        72693398
#
# [487 rows x 4 columns]

# %%
data_result = pd.merge(data_store1, data_store2)

# %%
data_result
# Out:
#     서비스_업종  분기    상권  2018_분기당_매출_금액  2019_분기당_매출_금액
# 0       가구   1  관광특구       164612528        83818931
# 1       가구   2  관광특구        91182170        31849831
# 2       가구   3  관광특구        72585550       108941425
# 3       가구   4  관광특구       110123421        25730309
# 4       가방   1  골목상권       101631313        87329154
# ..     ...  ..   ...             ...             ...
# 476     화초   3  관광특구       203818811       130906166
# 477     화초   3  발달상권        59931513        63985968
# 478     화초   4  골목상권       121222651        32097646
# 479     화초   4  관광특구       187898257       146360995
# 480     화초   4  발달상권        77441648        72693398
#
# [481 rows x 5 columns]

# %%
data_store3
# Out:
#     서비스_업종  분기    상권  2020_분기당_매출_금액
# 0       가구   1  관광특구      65358805.0
# 1       가구   2  관광특구      91867272.0
# 2       가구   3  관광특구     101055416.0
# 3       가구   4  관광특구      64112350.0
# 4       가방   1  골목상권      48476233.0
# ..     ...  ..   ...             ...
# 471     화초   3  관광특구      74888705.0
# 472     화초   3  발달상권      25394659.0
# 473     화초   4  골목상권      23116509.0
# 474     화초   4  관광특구      90018303.0
# 475     화초   4  발달상권      35774533.0
#
# [476 rows x 4 columns]

# %%
data_result = pd.merge(data_result, data_store3)

# %%
data_result
# Out:
#     서비스_업종  분기    상권  2018_분기당_매출_금액  2019_분기당_매출_금액  2020_분기당_매출_금액
# 0       가구   1  관광특구       164612528        83818931      65358805.0
# 1       가구   2  관광특구        91182170        31849831      91867272.0
# 2       가구   3  관광특구        72585550       108941425     101055416.0
# 3       가구   4  관광특구       110123421        25730309      64112350.0
# 4       가방   1  골목상권       101631313        87329154      48476233.0
# ..     ...  ..   ...             ...             ...             ...
# 448     화초   3  관광특구       203818811       130906166      74888705.0
# 449     화초   3  발달상권        59931513        63985968      25394659.0
# 450     화초   4  골목상권       121222651        32097646      23116509.0
# 451     화초   4  관광특구       187898257       146360995      90018303.0
# 452     화초   4  발달상권        77441648        72693398      35774533.0
#
# [453 rows x 6 columns]

# %%
data_result.to_csv('./data_result.csv',encoding='euc-kr')

# %%
price.to_csv('./price.csv',encoding='euc-kr')

# %%
price2 = pd.DataFrame(data_result['2020_분기당_매출_금액'] - data_result['2019_분기당_매출_금액'])

# %%
price2.columns = ['2019~2020_증감액']

# %%
price2.to_csv('./price2.csv',encoding='euc-kr')

# %%
price3 = pd.DataFrame(price['2018~2019_증감액'] / data_result['2018_분기당_매출_금액']*100)

# %%
price3
# Out:
#              0
# 0   -49.081074
# 1   -65.070111
# 2    50.086932
# 3   -76.635026
# 4   -14.072591
# ..         ...
# 448 -35.773266
# 449   6.765147
# 450 -73.521742
# 451 -22.106252
# 452  -6.131391
#
# [453 rows x 1 columns]

# %%
price3.columns = ['2018~2019_증감율']

# %%
price3.to_csv('./price3.csv',encoding='euc-kr')

# %%
price4 = pd.DataFrame(price2['2019~2020_증감액'] / data_result['2019_분기당_매출_금액']*100)

# %%
price4
# Out:
#               0
# 0    -22.023815
# 1    188.438805
# 2     -7.238761
# 3    149.170540
# 4    -44.490207
# ..          ...
# 448  -42.792072
# 449  -60.312144
# 450  -27.980672
# 451  -38.495702
# 452  -50.787095
#
# [453 rows x 1 columns]
